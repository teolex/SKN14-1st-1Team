# %%
import pandas as pd

pd.read_csv("C:\Workspaces\SKN14-1st-1Team\Safercar_data.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\isdjf\AppData\Local\Temp\ipykernel_15536\1635478465.py:3: SyntaxWarning: invalid escape sequence '\W'
#   pd.read_csv("C:\Workspaces\SKN14-1st-1Team\Safercar_data.csv")
# C:\Users\isdjf\AppData\Local\Temp\ipykernel_15536\1635478465.py:3: DtypeWarning: Columns (22,36,39,42,43,52,55,58,61,72,73,75,115,123,126,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("C:\Workspaces\SKN14-1st-1Team\Safercar_data.csv")
#         MAKE           MODEL  MODEL_YR BODY_STYLE VEHICLE_TYPE DRIVE_TRAIN  \
# 0      ACURA             ADX      2025        SUV          MPV         AWD
# 1      ACURA             ADX      2025        SUV          MPV         FWD
# 2      ACURA         INTEGRA      2025       5 HB           PC         FWD
# 3      ACURA  INTEGRA TYPE-S      2025       5 HB           PC         FWD
# ...

# %%
df = pd.read_csv("Safercar_data.csv")
df.shape
df.head()
# Out:
# C:\Users\isdjf\AppData\Local\Temp\ipykernel_15536\1429267428.py:1: DtypeWarning: Columns (22,36,39,42,43,52,55,58,61,72,73,75,115,123,126,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Safercar_data.csv")
#     MAKE           MODEL  MODEL_YR BODY_STYLE VEHICLE_TYPE DRIVE_TRAIN  \
# 0  ACURA             ADX      2025        SUV          MPV         AWD
# 1  ACURA             ADX      2025        SUV          MPV         FWD
# 2  ACURA         INTEGRA      2025       5 HB           PC         FWD
# 3  ACURA  INTEGRA TYPE-S      2025       5 HB           PC         FWD
# 4  ACURA             MDX      2025        SUV          MPV         AWD
#
#    PRODUCTION_RELEASE VEHICLE_CLASS BODY_FRAME NUM_OF_SEATING  ...  \
# 0                   1           NaN                         5  ...
# 1                   1           NaN                         5  ...
# 2                   1           NaN                         5  ...
# ...

# %%
df.tail()
df = df.drop_duplicates([])
